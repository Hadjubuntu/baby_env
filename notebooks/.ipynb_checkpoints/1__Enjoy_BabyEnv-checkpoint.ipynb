# %% [markdown]
# # Enjoy  BabyEnv
#
# See observation data, action space and all stuff contained in BabyEnv

# %%
import gym
import json
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

import baby.envs
from baby.envs.baby_env import default_conf

# %%
# Create env
env = gym.make('baby-v0')

# %%
# Check observation space
env.observation_space
# Out:
# Box(9, 21, 21)

# %%
# Check action space
env.action_space
# Out:
# Discrete(189)

# %%
# See full configuration
print(json.dumps(env.conf, indent=4))
# Out:
# {
#     "seed": 0,
#     "n_frame": 20,
#     "n-xaxis": 21,
#     "n-yaxis": 9,
#     "max_episode_iteration": 1000,
#     "alpha_ground_truth": 0.8,
#     "validation_threshold": 0.5,
#     "sigma_prediction": 1.0,
#     "reward": {
#         "timestep": 0,
#         "validation": 1
#     }
# }

# %% [markdown]
# ### Ground-truth
# Ground truth are matrix generated with numpy random and filter gaussian
# in oder to have geographical consistency between frames

# %%
# Take first n frames
n=10

env.reset()
first_frame_truth = env.ground_truth[:, :, :n]
first_frame_truth = np.swapaxes(first_frame_truth, axis1=-1, axis2=0)

# %%
for num, frame in enumerate(first_frame_truth):
    print(f"Frame #{num} | shape={frame.shape}")
    
    # For visual representation flip vertical axis
    frame_repr = np.flip(frame, axis=0)
    
    # Show into notebook in grayscale
    plt.imshow(frame, cmap='gray', vmin=0.0, vmax=1.0, interpolation='nearest', aspect='auto')
    plt.show()
# Out:
# Frame #0 | shape=(21, 9)
# Frame #1 | shape=(21, 9)
# Frame #2 | shape=(21, 9)
# Frame #3 | shape=(21, 9)
# Frame #4 | shape=(21, 9)
# Frame #5 | shape=(21, 9)
# Frame #6 | shape=(21, 9)
# Frame #7 | shape=(21, 9)
# Frame #8 | shape=(21, 9)
# Frame #9 | shape=(21, 9)

# %%
# Visual evolution of a single point (0, 0) over n frames
n=50
truth_evo = env.ground_truth[0, 0, :n]
plt.plot(truth_evo)
plt.title(f'Ground-truth evolution over {n} frames')
plt.xlabel('Frames')
plt.ylabel('Value')
plt.show()

# %%
# Overall statistics over frames
print(f"Mean ground truth: {np.mean(env.ground_truth)}")
print(f"Std deviation ground truth: {np.std(env.ground_truth)}")
# Out:
# Mean ground truth: 0.5163241333509733
# Std deviation ground truth: 0.30487247723217065

# %% [markdown]
# ## Impact of alpha_ground_truth on ground truth evolution
# Modifying conf to see different options

# %%
stored_ground_truth_prev_value = np.copy(env.ground_truth[0, 0, :n])
origin_alpha = env.conf['alpha_ground_truth']
env.conf['alpha_ground_truth'] = 2.0

# Reset ground truth
env.reset()

plt.plot(stored_ground_truth_prev_value, label=f"Evolution with {origin_alpha}")
plt.plot(env.ground_truth[0, 0, :n], label=f"Evolution with {env.conf['alpha_ground_truth']}")
plt.title(f'Ground-truth evolution over {n} frames')
plt.xlabel('Frames')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
# Restore old value
env.conf['alpha_ground_truth'] = origin_alpha

# %% [markdown]
# ## Forecast compared to ground-truth

# %%
def show_prediction_ground_truth():
    obs = env.reset()

    plt.figure(figsize=obs.shape[:2])
    columns = 2

    t = 0
    i_plt = 0

    for i in range(env.conf['n_frame']):
        
        error = obs[:, :, i] - env.ground_truth[:, :, t]
        print(f"Frame {i} // Mean error = {np.mean(error)} // std = {np.std(error)}")
        
        plt.subplot(2*env.conf['n_frame'] / columns + 1, columns, i_plt + 1)
        plt.imshow(obs[:,:,i], cmap='gray', vmin=0., vmax=1., interpolation='nearest', aspect='auto')

        i_plt += 1

        plt.subplot(2*env.conf['n_frame'] / columns + 1, columns, i_plt + 1)
        plt.imshow(env.ground_truth[:,:,t], cmap='gray', vmin=0., vmax=1., interpolation='nearest', aspect='auto')

        i_plt += 1

        t += i

# %%
# Show with initial configuration
show_prediction_ground_truth()
# Out:
# Mean error = 3.6126304769548746e-17 // std = 0.03125902258359721
# Mean error = 0.010454585078363946 // std = 0.061215355484331595
# Mean error = -0.019575153642729343 // std = 0.10407419867521163
# Mean error = 1.985478213350809e-16 // std = 0.13367093732374075
# Mean error = 0.04562616784967638 // std = 0.18575832009026585
# Mean error = 0.015388334742587313 // std = 0.2556867622746483
# Mean error = -0.012636216637341916 // std = 0.30176866267702657
# Mean error = -0.0031477746428359146 // std = 0.3152821279658738
# Mean error = 0.003979668632770844 // std = 0.3269046791974777
# Mean error = -0.05977713986717776 // std = 0.31863744163851426
# Mean error = -0.11842561272542194 // std = 0.3305541039709492
# Mean error = -0.08452470902281868 // std = 0.3263586990086821
# Mean error = -0.05317039061326478 // std = 0.31992370694341826
# Mean error = -0.10990636659559133 // std = 0.32091022694483023
# Mean error = -0.13373068385044368 // std = 0.32846261616657474
# Mean error = -0.12054593882866256 // std = 0.30527436350793535
# Mean error = -0.08904241188104871 // std = 0.3105131306743198
# Mean error = -0.10129168234138176 // std = 0.3046300905922573
# Mean error = -0.04141742557494881 // std = 0.29436039939957076
# Mean error = -0.10725704402175258 // std = 0.3094261617194493

# %%
original_sigma=env.conf['sigma_prediction']

env.conf['sigma_prediction']=0.5
show_prediction_ground_truth()
env.conf['sigma_prediction']=original_sigma
# Out:
# Mean error = -3.3776626410553705e-17 // std = 0.011308869132518858
# Mean error = 0.005146184861003084 // std = 0.06940489972760484
# Mean error = 0.011130961680454125 // std = 0.08936307076258698
# Mean error = 8.517584051357021e-17 // std = 0.10230592361131814
# Mean error = 0.00866466801045879 // std = 0.15290536518844106
# Mean error = -0.027995701966572136 // std = 0.20825825780377263
# Mean error = 0.016010334562602858 // std = 0.23937559699152217
# Mean error = 0.1087465205343663 // std = 0.2737374168581467
# Mean error = 0.05624053023232031 // std = 0.28541512410410236
# Mean error = 0.08035776331396939 // std = 0.2892907596888076
# Mean error = 0.018019225350160623 // std = 0.3199860226593561
# Mean error = 0.04132451178061225 // std = 0.32328019011632425
# Mean error = -0.012892640823160648 // std = 0.3315282093734185
# Mean error = -0.03464810459467375 // std = 0.2854072293392845
# Mean error = -0.032847676172355546 // std = 0.2913370091959184
# Mean error = -0.09709287031585064 // std = 0.3030590926187407
# Mean error = -0.07772174226594573 // std = 0.3145397668626883
# Mean error = -0.03465676147041344 // std = 0.28693835751547137
# Mean error = -0.04830653371403325 // std = 0.30669419338212633
# Mean error = -0.006061030131701504 // std = 0.3314688927534614
