# %% [markdown]
# # Enjoy  BabyEnv
#
# See observation data, action space and all stuff contained in BabyEnv

# %%
import gym
import json
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

import baby.envs
from baby.envs.baby_env import default_conf

# %%
# Create env
env = gym.make('baby-v0')

# %%
# Check observation space
env.observation_space
# Out:
# Box(9, 21, 21)

# %%
# Check action space
env.action_space
# Out:
# Discrete(189)

# %%
# See full configuration
print(json.dumps(env.conf, indent=4))
# Out:
# {
#     "seed": 0,
#     "n_frame": 20,
#     "n-xaxis": 21,
#     "n-yaxis": 9,
#     "max_episode_iteration": 1000,
#     "alpha_ground_truth": 0.8,
#     "validation_threshold": 0.8,
#     "sigma_prediction": 0.0,
#     "gamma_gaussian_value": 0.0,
#     "sigma_gaussian_value": 0.0,
#     "reward": {
#         "timestep": 0,
#         "validation": 1
#     }
# }

# %% [markdown]
# ### Ground-truth
# Ground truth are matrix generated with numpy random and filter gaussian
# in oder to have geographical consistency between frames

# %%
# Take first n frames
n=10

env.reset()
first_frame_truth = env.ground_truth[:, :, :n]
first_frame_truth = np.swapaxes(first_frame_truth, axis1=-1, axis2=0)

# %%
for num, frame in enumerate(first_frame_truth):
    print(f"Frame #{num} | shape={frame.shape}")
    
    # For visual representation flip vertical axis
    frame_repr = np.flip(frame, axis=0)
    
    # Show into notebook in grayscale
    plt.imshow(frame, cmap='gray', vmin=0.0, vmax=1.0, interpolation='nearest', aspect='auto')
    plt.show()
# Out:
# Frame #0 | shape=(21, 9)
# Frame #1 | shape=(21, 9)
# Frame #2 | shape=(21, 9)
# Frame #3 | shape=(21, 9)
# Frame #4 | shape=(21, 9)
# Frame #5 | shape=(21, 9)
# Frame #6 | shape=(21, 9)
# Frame #7 | shape=(21, 9)
# Frame #8 | shape=(21, 9)
# Frame #9 | shape=(21, 9)

# %%
# Visual evolution of a single point (0, 0) over n frames
n=50
truth_evo = env.ground_truth[0, 0, :n]
plt.plot(truth_evo)
plt.title(f'Ground-truth evolution over {n} frames')
plt.xlabel('Frames')
plt.ylabel('Value')
plt.show()

# %%
# Overall statistics over frames
print(f"Mean ground truth: {np.mean(env.ground_truth)}")
print(f"Std deviation ground truth: {np.std(env.ground_truth)}")
# Out:
# Mean ground truth: 0.5163241333509733
# Std deviation ground truth: 0.30487247723217065

# %% [markdown]
# ## Impact of alpha_ground_truth on ground truth evolution
# Modifying conf to see different options

# %%
stored_ground_truth_prev_value = np.copy(env.ground_truth[0, 0, :n])
origin_alpha = env.conf['alpha_ground_truth']
env.conf['alpha_ground_truth'] = 2.0

# Reset ground truth
env.reset()

plt.plot(stored_ground_truth_prev_value, label=f"Evolution with {origin_alpha}")
plt.plot(env.ground_truth[0, 0, :n], label=f"Evolution with {env.conf['alpha_ground_truth']}")
plt.title(f'Ground-truth evolution over {n} frames')
plt.xlabel('Frames')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
# Restore old value
env.conf['alpha_ground_truth'] = origin_alpha

# %% [markdown]
# ## Forecast compared to ground-truth

# %%
def show_prediction_ground_truth():
    obs = env.reset()
    print(f"Show pred/truth with sigma={env.conf['sigma_prediction']}")

    plt.figure(figsize=obs.shape[:2])
    columns = 2
    
    t=0
    i_plt = 0

    for i in range(0,env.conf['n_frame']):
        error = obs[:, :, i] - env.ground_truth[:, :, t]
        print(f"Frame {i} // Mean error = {np.mean(error)} // std = {np.std(error)}")
        
        plt.subplot(2*env.conf['n_frame'] / columns + 1, columns, i_plt + 1)
        plt.imshow(obs[:,:,i], cmap='gray', vmin=0., vmax=1., interpolation='nearest', aspect='auto')

        i_plt += 1

        plt.subplot(2*env.conf['n_frame'] / columns + 1, columns, i_plt + 1)
        plt.imshow(env.ground_truth[:,:,t], cmap='gray', vmin=0., vmax=1., interpolation='nearest', aspect='auto')

        i_plt += 1
        
        t=i+1

# %%
# Show with initial configuration
show_prediction_ground_truth()
# Out:
# Show pred/truth with sigma=0.0
# Frame 0 // Mean error = 0.0 // std = 0.0
# Frame 1 // Mean error = 0.0 // std = 0.0
# Frame 2 // Mean error = 0.0 // std = 0.0
# Frame 3 // Mean error = 0.0 // std = 0.0
# Frame 4 // Mean error = 0.0 // std = 0.0
# Frame 5 // Mean error = 0.0 // std = 0.0
# Frame 6 // Mean error = 0.0 // std = 0.0
# Frame 7 // Mean error = 0.0 // std = 0.0
# Frame 8 // Mean error = 0.0 // std = 0.0
# Frame 9 // Mean error = 0.0 // std = 0.0
# Frame 10 // Mean error = 0.0 // std = 0.0
# Frame 11 // Mean error = 0.0 // std = 0.0
# Frame 12 // Mean error = 0.0 // std = 0.0
# Frame 13 // Mean error = 0.0 // std = 0.0
# Frame 14 // Mean error = 0.0 // std = 0.0
# Frame 15 // Mean error = 0.0 // std = 0.0
# Frame 16 // Mean error = 0.0 // std = 0.0
# Frame 17 // Mean error = 0.0 // std = 0.0
# Frame 18 // Mean error = 0.0 // std = 0.0
# Frame 19 // Mean error = 0.0 // std = 0.0

# %%
original_sigma=env.conf['sigma_prediction']

env.conf['sigma_prediction']=0.00
env.conf['gamma_gaussian_value']=0.0
env.conf['sigma_gaussian_value']=0.00001
show_prediction_ground_truth()
env.conf['sigma_prediction']=original_sigma
# Out:
# Show pred/truth with sigma=0.0
# Frame 0 // Mean error = 0.0 // std = 0.0
# Frame 1 // Mean error = 0.005756629628464611 // std = 0.06416419036328691
# Frame 2 // Mean error = 0.018672718509996022 // std = 0.06090727309406695
# Frame 3 // Mean error = 0.05738827466813141 // std = 0.08315972774054185
# Frame 4 // Mean error = 0.0019082400111016782 // std = 0.07676009363811906
# Frame 5 // Mean error = 0.005751504073688662 // std = 0.06201499985684598
# Frame 6 // Mean error = -0.00980723497828852 // std = 0.06236808500304084
# Frame 7 // Mean error = 0.0219097104640842 // std = 0.07898534425149928
# Frame 8 // Mean error = -0.010485597721587149 // std = 0.06766190905488129
# Frame 9 // Mean error = -0.002281650336010858 // std = 0.07496355326339416
# Frame 10 // Mean error = 0.00998822023302817 // std = 0.07366027154471073
# Frame 11 // Mean error = -0.02544442572215642 // std = 0.08383178049785837
# Frame 12 // Mean error = -0.016908969697120014 // std = 0.06353579941504953
# Frame 13 // Mean error = -0.0229144296420455 // std = 0.0728363112561261
# Frame 14 // Mean error = -0.008098490282335358 // std = 0.057145632296242255
# Frame 15 // Mean error = -0.019289161513081684 // std = 0.07661955448823542
# Frame 16 // Mean error = 0.014368959433700115 // std = 0.07368153318598174
# Frame 17 // Mean error = 0.005971182144059726 // std = 0.08250063539816656
# Frame 18 // Mean error = -0.000330668867340327 // std = 0.06908096915552336
# Frame 19 // Mean error = -0.007896657468572316 // std = 0.07343177803976365
