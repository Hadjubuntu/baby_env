# %% [markdown]
# # Enjoy  BabyEnv
#
# See observation data, action space and all stuff contained in BabyEnv

# %%
import gym
import json
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

import baby.envs
from baby.envs.baby_env import default_conf

# %%
default_conf
# Out:
# {'seed': 0,
#  'n_frame': 20,
#  'n-xaxis': 21,
#  'n-yaxis': 9,
#  'max_episode_iteration': 1000,
#  'alpha_ground_truth': 0.8,
#  'alpha_slow_ground_truth': 0.1,
#  'alpha_slow_freq': 2,
#  'validation_threshold': 0.8,
#  'sigma_prediction': 1.0,
#  'gamma_gaussian_value': 1.5,
#  'sigma_gaussian_value': 2.0,
#  'reward': {'timestep': 0, 'validation': 1, 'done': 0}}

# %%
# Create env
env = gym.make('baby-v0')

# %%
# Check observation space
env.observation_space
# Out:
# Box(9, 21, 21)

# %%
# Check action space
env.action_space
# Out:
# Discrete(189)

# %%
# See full configuration
print(json.dumps(env.conf, indent=4))
# Out:
# {
#     "seed": 0,
#     "n_frame": 20,
#     "n-xaxis": 21,
#     "n-yaxis": 9,
#     "max_episode_iteration": 1000,
#     "alpha_ground_truth": 0.8,
#     "alpha_slow_ground_truth": 0.1,
#     "alpha_slow_freq": 2,
#     "validation_threshold": 0.8,
#     "sigma_prediction": 1.0,
#     "gamma_gaussian_value": 1.5,
#     "sigma_gaussian_value": 2.0,
#     "reward": {
#         "timestep": 0,
#         "validation": 1,
#         "done": 0
#     }
# }

# %%
env.conf['sigma_prediction'] = 0.3
env.conf['gamma_gaussian_value'] = 0.05
env.conf['sigma_gaussian_value'] = 0.1

# %% [markdown]
# ### Ground-truth
# Ground truth are matrix generated with numpy random and filter gaussian
# in oder to have geographical consistency between frames

# %%
# Take first n frames
n=10

env.reset()
first_frame_truth = env.ground_truth[:, :, :n]
first_frame_truth = np.swapaxes(first_frame_truth, axis1=-1, axis2=0)

# %%
for num, frame in enumerate(first_frame_truth):
    print(f"Frame #{num} | shape={frame.shape}")
    
    # For visual representation flip vertical axis
    frame_repr = np.flip(frame, axis=0)
    
    # Show into notebook in grayscale
    plt.imshow(frame, cmap='gray', vmin=0.0, vmax=1.0, interpolation='nearest', aspect='auto')
    plt.show()
# Out:
# Frame #0 | shape=(21, 9)
# Frame #1 | shape=(21, 9)
# Frame #2 | shape=(21, 9)
# Frame #3 | shape=(21, 9)
# Frame #4 | shape=(21, 9)
# Frame #5 | shape=(21, 9)
# Frame #6 | shape=(21, 9)
# Frame #7 | shape=(21, 9)
# Frame #8 | shape=(21, 9)
# Frame #9 | shape=(21, 9)

# %%
# Visual evolution of a single point (0, 0) over n frames
n=50
truth_evo = env.ground_truth[0, 0, :n]
plt.plot(truth_evo)
plt.title(f'Ground-truth evolution over {n} frames')
plt.xlabel('Frames')
plt.ylabel('Value')
plt.show()

# %%
# Overall statistics over frames
print(f"Mean ground truth: {np.mean(env.ground_truth)}")
print(f"Std deviation ground truth: {np.std(env.ground_truth)}")
# Out:
# Mean ground truth: 0.5429393203414927
# Std deviation ground truth: 0.29667459198928897

# %% [markdown]
# ## Impact of alpha_ground_truth on ground truth evolution
# Modifying conf to see different options

# %%
stored_ground_truth_prev_value = np.copy(env.ground_truth[0, 0, :n])
origin_alpha = env.conf['alpha_ground_truth']
env.conf['alpha_ground_truth'] = 2.0
env.conf['alpha_slow_ground_truth'] = 1.0

# Reset ground truth
env.reset()

plt.plot(stored_ground_truth_prev_value, label=f"Evolution with {origin_alpha}")
plt.plot(env.ground_truth[0, 0, :n], label=f"Evolution with {env.conf['alpha_ground_truth']}")
plt.title(f'Ground-truth evolution over {n} frames')
plt.xlabel('Frames')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
# Restore old value
env.conf['alpha_ground_truth'] = origin_alpha

# %% [markdown]
# ## Forecast compared to ground-truth

# %%
env.conf['sigma_prediction'] = 0.3
env.conf['gamma_gaussian_value'] = 0.05
env.conf['sigma_gaussian_value'] = 0.1


def show_prediction_ground_truth():
    obs = env.reset()
    print(f"Show pred/truth with sigma={env.conf['sigma_prediction']}")

    plt.figure(figsize=obs.shape[:2])
    columns = 2
    
    t=0
    i_plt = 0

    for i in range(0,env.conf['n_frame']):
        error = obs[:, :, i] - env.ground_truth[:, :, t]
        print(f"Frame {i} // Mean error = {np.mean(error)} // std = {np.std(error)}")
        
        plt.subplot(2*env.conf['n_frame'] / columns + 1, columns, i_plt + 1)
        plt.imshow(obs[:,:,i], cmap='gray', vmin=0., vmax=1., interpolation='nearest', aspect='auto')

        i_plt += 1

        plt.subplot(2*env.conf['n_frame'] / columns + 1, columns, i_plt + 1)
        plt.imshow(env.ground_truth[:,:,t], cmap='gray', vmin=0., vmax=1., interpolation='nearest', aspect='auto')

        i_plt += 1
        
        t=i+1

# %%
# Show with initial configuration
show_prediction_ground_truth()
# Out:
# Show pred/truth with sigma=0.2
# Frame 0 // Mean error = -0.0016802006438566936 // std = 0.19462288486675391
# Frame 1 // Mean error = -0.006607195668483028 // std = 0.26375788780873904
# Frame 2 // Mean error = 0.00902016139887339 // std = 0.3008929138314169
# Frame 3 // Mean error = 0.011052310487392424 // std = 0.3360293214031984
# Frame 4 // Mean error = -0.03676626125569459 // std = 0.3764804623946309
# Frame 5 // Mean error = -0.05880510836197848 // std = 0.3775361986281491
# Frame 6 // Mean error = 0.038926664517815124 // std = 0.4056163590046183
# Frame 7 // Mean error = -0.024671668055670795 // std = 0.45471725142494956
# Frame 8 // Mean error = 0.009940959148664205 // std = 0.47033506574936185
# Frame 9 // Mean error = -0.007113002938422547 // std = 0.4494856301784234
# Frame 10 // Mean error = 0.05234124882612267 // std = 0.4463512301727607
# Frame 11 // Mean error = 0.06584558916841955 // std = 0.4936013838548594
# Frame 12 // Mean error = 0.008422820917311537 // std = 0.515792734262872
# Frame 13 // Mean error = -0.002284079275371081 // std = 0.47464028886694426
# Frame 14 // Mean error = 0.053081463772582015 // std = 0.48754714969850765
# Frame 15 // Mean error = 0.044735317645850294 // std = 0.5024043827590278
# Frame 16 // Mean error = 0.013719100686669823 // std = 0.5181933875325704
# Frame 17 // Mean error = -0.04383171598409824 // std = 0.5200590243883187
# Frame 18 // Mean error = -0.002204821497012416 // std = 0.5087665334709168
# Frame 19 // Mean error = -0.04569162011592944 // std = 0.5051619652443975

# %%
env.conf['sigma_prediction'] = 0.3
env.conf['gamma_gaussian_value'] = 0.05
env.conf['sigma_gaussian_value'] = -0.1


show_prediction_ground_truth()
# Out:
# Show pred/truth with sigma=0.4
# Frame 0 // Mean error = -0.0033080786403329988 // std = 0.31339020850398364
# Frame 1 // Mean error = 0.04553933900999568 // std = 0.37702595522886634
# Frame 2 // Mean error = 0.043023192245559574 // std = 0.4062373916030569
# Frame 3 // Mean error = 0.0020744310266431823 // std = 0.44021166431870323
# Frame 4 // Mean error = 0.0583041015675092 // std = 0.4788085134567483
# Frame 5 // Mean error = 0.06344781938986985 // std = 0.48771292772952873
# Frame 6 // Mean error = 0.0771970048503503 // std = 0.5066405017224824
# Frame 7 // Mean error = 0.09360425823787207 // std = 0.5042821635358331
# Frame 8 // Mean error = 0.1143030525912727 // std = 0.5349298794511265
# Frame 9 // Mean error = 0.10695798176957091 // std = 0.5153655630020619
# Frame 10 // Mean error = 0.06314744128962926 // std = 0.5161430715703923
# Frame 11 // Mean error = 0.007758434072086684 // std = 0.5095980585589014
# Frame 12 // Mean error = 0.05758220592756652 // std = 0.5354936030016878
# Frame 13 // Mean error = 0.04149502252406056 // std = 0.521741757521612
# Frame 14 // Mean error = 0.038837967395644525 // std = 0.5303679369438618
# Frame 15 // Mean error = 0.09450000023368856 // std = 0.5874021765551171
# Frame 16 // Mean error = 0.009594076292741383 // std = 0.5514404902967555
# Frame 17 // Mean error = 0.10095724263706184 // std = 0.5705074657493192
# Frame 18 // Mean error = 0.14146943153543398 // std = 0.505276203688841
# Frame 19 // Mean error = 0.08112374581603206 // std = 0.5331129086993405
